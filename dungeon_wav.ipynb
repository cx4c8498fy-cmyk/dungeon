# %%
floor=100
(floor - 1) // 10
# Out:
# 9

# %%
import random
emy_typ = 7
emy_lifemax = 1000
boss = 0

print(int (1500 *(emy_typ //21 )+emy_lifemax //10 )-boss *random .randint (emy_typ *43 ,emy_typ *43 +10 ))
print(int (emy_lifemax //10 + random .randint (-emy_lifemax//100, emy_lifemax//100)))
print(emy_lifemax //10 + random .randint (-emy_lifemax//100, emy_lifemax//100))
# Out:
# 100
# 100
# 107
